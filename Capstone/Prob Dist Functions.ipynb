# %%
import numpy as np
import scipy

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy import stats

# %%
x = np.arange(-4,4,0.01)

# %%
plt.plot(x, stats.chi2(0.0).pdf(x))

# %%
stats.norm?

# %%
from scipy.stats import logistic
fig, ax = plt.subplots(1, 1)

for dist in [stats.norm, stats.logistic ]:
    print dist.name
    #Calculate a few first moments:
    mean, var, skew, kurt = dist.stats(moments='mvsk')
    print mean, var, skew, kurt

    #Display the probability density function (``pdf``):

    x = np.linspace(dist.ppf(0.01),
                     dist.ppf(0.99), 100)
    ax.plot(x, dist.logpdf(x),
            '-', lw=5, alpha=0.6, label=str(dist.name) + ' pdf')

plt.legend()
# Out:
# norm
# 0.0 1.0 0.0 0.0
# logistic
# 0.0 3.2898681337 0.0 1.2
