# %%
# !ls *.h5
# Out:
# eurusd_2012_sequences_20.h5
# eurusd_2012_sequences_60.h5
# results.h5
# sequences_30_EURUSD_GBPUSD_EURGBP_2012.h5
# xauusd_2012_sequences_20.h5
# xauusd_2012_sequences_60.h5

# %%
import h5py

# %%
with h5py.File('eurusd_2012_sequences_20.h5', 'r') as f:
    sequences = f['sequences'][...]

# %%
sequences.shape
# Out:
# (359008, 20)

# %%
n = 1000
sl = 20
rseq = np.zeros(1000)

# %%
from sklearn.decomposition import PCA,FastICA

# %%
pca = PCA(10)
#pca = FastICA(5)

# %%
pca.fit(sequences[:,:10])
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[-0.20650011,  0.37131324, -0.41330544,  0.35466573, -0.13717175,
#         -0.15340683,  0.36675512, -0.41653805,  0.36490553, -0.19838338],
#        [-0.23345006,  0.259364  , -0.02274518, -0.31534004,  0.53217116,
#         -0.5256809 ,  0.30073142,  0.03758842, -0.26809752,  0.23451992],
#        [-0.2026226 ,  0.45291079, -0.42278342,  0.24457096, -0.14543225,
#          0.15884604, -0.29072666,  0.46289867, -0.39506463,  0.11831859],
#        [-0.47871748,  0.28717623,  0.29882395, -0.29898129,  0.08459988,
#          0.06627054, -0.25697149,  0.2201478 ,  0.36188623, -0.50265679],
#        [ 0.15990211,  0.14388497, -0.3913109 , -0.32533544,  0.44757939,
#          0.42254506, -0.34951569, -0.38000779,  0.16266872,  0.15119911],
#        [ 0.07029979, -0.31598126, -0.20905128,  0.42411482,  0.40480891,
#         -0.43225512, -0.40507407,  0.23185826,  0.31081037, -0.08047915],
#        [-0.59887577, -0.1155601 ,  0.26750936,  0.23100385, -0.05748629,
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame()
for i,seq in enumerate(pca.components_):
    df['comp-%s' %i] = seq
df.plot(subplots=True,figsize=(20,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1231e1e50>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x12485d810>], dtype=object)

# %%
pca.explained_variance_ratio_
# Out:
# array([ 0.103144  ,  0.10281429,  0.10174765,  0.10172931,  0.10052273,
#         0.10047171,  0.09989954,  0.09808756,  0.09734486,  0.09423837])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.99999999999999978

# %% [markdown]
# ##  Summary - PCA / ICA don't reveal any particular structure to the data
